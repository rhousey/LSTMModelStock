# %% [markdown]
# # LSTM Model Stock Price Prediction AMZN

# %% [markdown]
# ## Imports

# %%
from datetime import date, timedelta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import yfinance as yf
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
data = yf.download('AMZN', start=(date.today() - timedelta(days=5000)),
                   end=date.today() - timedelta(days=30))
data["Date"] = data.index
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ## Filter by Close Price

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-12    7.000000    7.145500    6.984000    7.060000    7.060000
# 2010-04-13    7.061500    7.099000    6.956000    7.008000    7.008000
# 2010-04-14    7.017000    7.225000    6.960000    7.214000    7.214000
# 2010-04-15    7.227500    7.354500    7.200000    7.291000    7.291000
# 2010-04-16    7.244000    7.358500    7.072500    7.108500    7.108500
# ...                ...         ...         ...         ...         ...
# 2023-11-13  142.080002  143.229996  140.669998  142.589996  142.589996
# 2023-11-14  145.000000  147.259995  144.679993  145.800003  145.800003
# 2023-11-15  147.059998  147.289993  142.589996  143.199997  143.199997
# 2023-11-16  140.910004  143.320007  139.520004  142.830002  142.830002
# 2023-11-17  142.660004  145.229996  142.539993  145.179993  145.179993
#
#                Volume       Date
# Date
# 2010-04-12  108906000 2010-04-12
# 2010-04-13   95710000 2010-04-13
# ...

# %%
close_data = data["Close"].values.reshape(-1,1)
train_data, test_data = train_test_split(close_data, test_size = 0.15 , shuffle=False)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train_data = scaler.fit_transform(train_data)
scaled_test_data = scaler.fit_transform(test_data)

# %%
x_train = []
y_train = []
for i in range(100, train_data.shape[0]):
    x_train.append(scaled_train_data[i - 100:i])
    y_train.append(scaled_train_data[i,0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))
x_train.shape
# Out:
# (2812, 100, 1)

# %% [markdown]
# ## Building LSTM Model

# %%
model = Sequential()
# increasing layers, units tuning  
model.add(LSTM(units = 256, return_sequences = True, input_shape= (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 128, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 64))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_6 (LSTM)               (None, 100, 256)          264192
#
#  dropout (Dropout)           (None, 100, 256)          0
#
#  lstm_7 (LSTM)               (None, 100, 128)          197120
#
#  dropout_1 (Dropout)         (None, 100, 128)          0
#
#  lstm_8 (LSTM)               (None, 64)                49408
#
#  dense_6 (Dense)             (None, 25)                1625
#
#  dense_7 (Dense)             (None, 1)                 26
#
# ...
# Total params: 512371 (1.95 MB)
# Trainable params: 512371 (1.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf 

model.compile(optimizer = 'adam' , loss = 'mean_squared_error', metrics = [tf.keras.metrics.MeanAbsoluteError()])
# changed from epochs = 20, batch_size = 128 
model.fit(x_train, y_train, epochs = 50, batch_size = 64)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 17s 345ms/step - loss: 0.0095 - mean_absolute_error: 0.0518
# Epoch 2/50
# 44/44 [==============================] - 15s 336ms/step - loss: 5.0085e-04 - mean_absolute_error: 0.0135
# Epoch 3/50
# 44/44 [==============================] - 15s 340ms/step - loss: 5.3605e-04 - mean_absolute_error: 0.0134
# Epoch 4/50
# 44/44 [==============================] - 23s 528ms/step - loss: 4.2234e-04 - mean_absolute_error: 0.0120
# Epoch 5/50
# 44/44 [==============================] - 15s 341ms/step - loss: 4.3311e-04 - mean_absolute_error: 0.0124
# Epoch 6/50
# 44/44 [==============================] - 15s 331ms/step - loss: 4.1931e-04 - mean_absolute_error: 0.0119
# Epoch 7/50
# 44/44 [==============================] - 15s 331ms/step - loss: 3.8887e-04 - mean_absolute_error: 0.0117
# Epoch 8/50
# 44/44 [==============================] - 15s 335ms/step - loss: 3.8719e-04 - mean_absolute_error: 0.0114
# Epoch 9/50
# ...

# %%
X_test = []
y_test = []
for i in range(100,len(scaled_test_data)):
    X_test.append(scaled_test_data[i - 100:i, 0])
    y_test.append(scaled_test_data[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Predict using the trained model
y_pred = model.predict(X_test)

scale = 1 / scaler.scale_[0]
y_pred = y_pred * scale
y_test = y_test * scale
# Out:
# 13/13 [==============================] - 2s 72ms/step

# %%
test_dates = data.index[-len(scaled_test_data)+100:]
test_dates
# Out:
# DatetimeIndex(['2022-03-28', '2022-03-29', '2022-03-30', '2022-03-31',
#                '2022-04-01', '2022-04-04', '2022-04-05', '2022-04-06',
#                '2022-04-07', '2022-04-08',
#                ...
#                '2023-11-06', '2023-11-07', '2023-11-08', '2023-11-09',
#                '2023-11-10', '2023-11-13', '2023-11-14', '2023-11-15',
#                '2023-11-16', '2023-11-17'],
#               dtype='datetime64[ns]', name='Date', length=415, freq=None)

# %%
plt.figure(figsize=(28,12))
plt.plot(test_dates, y_test, color = 'blue', label = 'Price')
plt.plot(test_dates, y_pred, color = 'red', label = 'Predicted Price')
plt.xlabel('Time')
plt.title('Stock Price and Predicted Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Future Price Prediction of next day

# %%
newData = yf.download('AMZN', start=(date.today() - timedelta(days=45)),
                   end=date.today())
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
new_df = newData.filter(['Close'])
last30Days = new_df[-30:].values
last30Days_scaled = scaler.transform(last30Days)
X_test_data = [] 
X_test_data.append(last30Days_scaled)
X_test_data = np.array(X_test_data)
X_test_data = np.reshape(X_test_data, (X_test_data.shape[0], X_test_data.shape[1], 1))

# %%
predicted_price = model.predict(X_test_data)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
predicted_price = scaler.inverse_transform(predicted_price)

# %%
#for the next day // printed for 12/20/2023
print(predicted_price)
# Out:
# [[147.5158]]
